# %%
from ultralytics import YOLO
import cv2
import numpy as np
import cvzone

# %%
model = YOLO("C:/Users/Asus/Downloads/best.pt")
class_names = model.names
cap = cv2.VideoCapture("C:/Users/Asus/Downloads/pothole.mp4")
count = 0

# %%
while True:
    ret, img = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    
    img = cv2.resize(img, (1020, 500))
    h, w, _ = img.shape
    results = model.predict(img)

    for r in results:
        boxes = r.boxes  
        masks = r.masks  
        
    if masks is not None:
        masks = masks.data.cpu()
        for seg, box in zip(masks.data.cpu().numpy(), boxes):
            seg = cv2.resize(seg, (w, h))
            contours, _ = cv2.findContours((seg).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            for contour in contours:
                d = int(box.cls)
                c = class_names[d]
                x, y,x1,y1 = cv2.boundingRect(contour)
                cv2.polylines(img, [contour],True, color=(0, 0, 255), thickness=2)
                cv2.putText(img, c, (x,y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
                 
    cv2.imshow('img', img)
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 5 road-potholes, 354.7ms
# Speed: 5.0ms preprocess, 354.7ms inference, 23.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 road-potholes, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 11.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 road-potholes, 220.2ms
# Speed: 1.2ms preprocess, 220.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 road-potholes, 225.5ms
# Speed: 0.0ms preprocess, 225.5ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 road-potholes, 216.8ms
# Speed: 3.0ms preprocess, 216.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 road-potholes, 209.0ms
# Speed: 0.0ms preprocess, 209.0ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 road-potholes, 167.9ms
# Speed: 2.6ms preprocess, 167.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 road-potholes, 200.8ms
# Speed: 2.7ms preprocess, 200.8ms inference, 18.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 road-potholes, 280.1ms
# Speed: 5.0ms preprocess, 280.1ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 road-potholes, 276.3ms
# Speed: 0.0ms preprocess, 276.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 road-potholes, 280.1ms
# Speed: 0.0ms preprocess, 280.1ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 road-potholes, 212.7ms
# Speed: 3.1ms preprocess, 212.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 road-potholes, 201.4ms
# Speed: 8.0ms preprocess, 201.4ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)

# %% [markdown]
# <a href="https://colab.research.google.com/github/tar7nic/MultiScriptSense/blob/main/pothole-detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Dec 12 02:02:59 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.28                 Driver Version: 546.28       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   56C    P3              23W /  55W |      0MiB /  6144MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# %pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.9.0 torch-2.1.2+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# Setup complete  (20 CPUs, 15.6 GB RAM, 600.9/952.8 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DVczugEwIZ1WnWiaDxsh")
project = rf.workspace("tarnics").project("yolov8-pothole-detection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘{HOME}/datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to yolov8-pothole-detection-1 in yolov8:: 100%|██████████| 68/68 [00:00<00:00, 6662.76it/s]

# %%
# %cd {HOME}
# !yolo task=segment mode=train model=yolov8s-seg.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# ...
# 100% 22.8M/22.8M [00:00<00:00, 115MB/s]
# ...
